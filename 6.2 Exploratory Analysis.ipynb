# %% [markdown]
# # Table of Contents
#
# # 01. Importing Libraries
#
# # 02. Importing Data
#
# # 03. Correlation Matrix
#
# # 04. Scatterplots
#
# # 05. Pair Plots
#
# # 06. Categorical Plots
#
# # 07. Key Questions
#
# # 08. Hypotheses

# %% [markdown]
# # 01. Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib
import os

# %% [markdown]
# # 02. Importing Data

# %%
path = r'C:\Users\ketki\Desktop\Data Analytics bootcamp tasks\Data Immersion\Achievement 6'

# %%
path
# Out:
# 'C:\\Users\\ketki\\Desktop\\Data Analytics bootcamp tasks\\Data Immersion\\Achievement 6'

# %%
df_2015_prepared = pd.read_csv(os.path.join(path, 'Data', 'Prepared data', '2015_checked.csv'), index_col = False)

# %%
df_2016_prepared = pd.read_csv(os.path.join(path, 'Data', 'Prepared data', '2016_checked.csv'), index_col = False)

# %%
df_2017_prepared = pd.read_csv(os.path.join(path, 'Data', 'Prepared data', '2017_checked.csv'), index_col = False)

# %%
df_2018_prepared = pd.read_csv(os.path.join(path, 'Data', 'Prepared data', '2018_checked.csv'), index_col = False)

# %%
df_2019_prepared = pd.read_csv(os.path.join(path, 'Data', 'Prepared data', '2019_checked.csv' ), index_col = False)

# %% [markdown]
# # 03. Correlation matrix

# %%
# %matplotlib inline

# %%
df_2015_prepared.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Overall rank', 'Score', 'GDP per Capita',
#        'Social Support', 'Healthy Life Expectancy ',
#        'Freedom to make life choices', 'Perceptions of Corruption',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df_2015_prepared_sub = df_2015_prepared[['Country', 'Overall rank', 'GDP per Capita', 'Healthy Life Expectancy ', 'Freedom to make life choices','Perceptions of Corruption','Social Support']]

# %%
df_2015_prepared_sub
# Out:
#          Country  Overall rank  GDP per Capita  Healthy Life Expectancy   \
# 0    Switzerland             1         1.39651                   0.94143
# 1        Iceland             2         1.30232                   0.94784
# 2        Denmark             3         1.32548                   0.87464
# 3         Norway             4         1.45900                   0.88521
# 4         Canada             5         1.32629                   0.90563
# ..           ...           ...             ...                       ...
# 153       Rwanda           154         0.22208                   0.42864
# 154        Benin           155         0.28665                   0.31910
# 155        Syria           156         0.66320                   0.72193
# 156      Burundi           157         0.01530                   0.22396
# 157         Togo           158         0.20868                   0.28443
#
#      Freedom to make life choices  Perceptions of Corruption  Social Support
# ...

# %%
df_2015_prepared_sub.corr()
# Out:
#                               Overall rank  GDP per Capita  \
# Overall rank                      1.000000       -0.785267
# GDP per Capita                   -0.785267        1.000000
# Healthy Life Expectancy          -0.735613        0.816478
# Freedom to make life choices     -0.556886        0.370300
# Perceptions of Corruption        -0.372315        0.307885
# Social Support                   -0.733644        0.645299
#
#                               Healthy Life Expectancy   \
# Overall rank                                 -0.735613
# GDP per Capita                                0.816478
# Healthy Life Expectancy                       1.000000
# Freedom to make life choices                  0.360477
# Perceptions of Corruption                     0.248335
# Social Support                                0.531104
#
#                               Freedom to make life choices  \
# Overall rank                                     -0.556886
# ...

# %%
plt.matshow(df_2015_prepared_sub.corr())
plt.show()

# %%
f,ax = plt.subplots(figsize=(10,10))

corr_2015 = sns.heatmap(df_2015_prepared_sub.corr(), annot = True, ax=ax)

# %%
df_2016_prepared.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Overall Rank', 'Score', 'GDP per Capita',
#        'Social Support', 'Healthy Life Expectancy',
#        'Freedom to make Life choices', 'Perceptions of Corruption',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df_2016_prepared_sub = df_2016_prepared[['Country', 'Overall Rank','GDP per Capita', 'Social Support', 'Healthy Life Expectancy','Freedom to make Life choices','Perceptions of Corruption']]

# %%
df_2016_prepared_sub
# Out:
#          Country  Overall Rank  GDP per Capita  Social Support  \
# 0        Denmark             1         1.44178         1.16374
# 1    Switzerland             2         1.52733         1.14524
# 2        Iceland             3         1.42666         1.18326
# 3         Norway             4         1.57744         1.12690
# 4        Finland             5         1.40598         1.13464
# ..           ...           ...             ...             ...
# 152        Benin           153         0.39499         0.10419
# 153  Afghanistan           154         0.38227         0.11037
# 154         Togo           155         0.28123         0.00000
# 155        Syria           156         0.74719         0.14866
# 156      Burundi           157         0.06831         0.23442
#
#      Healthy Life Expectancy  Freedom to make Life choices  \
# 0                    0.79504                       0.57941
# 1                    0.86303                       0.58557
# ...

# %%
f,ax = plt.subplots(figsize=(10,10))

corr_2016 = sns.heatmap(df_2016_prepared_sub.corr(), annot = True, ax=ax)

# %%
df_2017_prepared.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Overall Rank', 'Score',
#        'Economy..GDP.per.Capita.', 'Social Support', 'Healthy Life Expectancy',
#        'Freedom to make Life Choices', 'Generosity',
#        'Perceptions of Corruption', 'Dystopia.Residual'],
#       dtype='object')

# %%
df_2017_prepared_sub = df_2017_prepared[['Country', 'Overall Rank','Economy..GDP.per.Capita.', 'Social Support','Healthy Life Expectancy','Freedom to make Life Choices','Perceptions of Corruption']]

# %%
f,ax = plt.subplots(figsize = (10,10))

corr_3 = sns.heatmap(df_2017_prepared_sub.corr(), annot = True, ax = ax)

# %%
df_2018_prepared.columns
# Out:
# Index(['Unnamed: 0', 'Overall rank', 'Country', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df_2018_prepared_sub = df_2018_prepared[['Overall rank','Country','GDP per capita','Social support', 'Healthy life expectancy','Freedom to make life choices','Perceptions of corruption']]

# %%
f,ax = plt.subplots(figsize=(10,10))

corr_4 = sns.heatmap(df_2018_prepared_sub.corr(), annot = True, ax=ax, center = 0)

# %%
df_2019_prepared.columns
# Out:
# Index(['Unnamed: 0', 'Overall rank', 'Country', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
df_2019_prepared_sub = df_2019_prepared[['Overall rank','Country','GDP per capita','Social support','Healthy life expectancy','Freedom to make life choices','Perceptions of corruption']]

# %%
f,ax = plt.subplots(figsize = (10,10))

corr_5 = sns.heatmap(df_2019_prepared_sub.corr(), annot = True, ax = ax)

# %% [markdown]
# ## The strongest correlation is between GDP per capita and healthy life expectancy, followed by the correlation between GDP per capita and social support. The next strongest correlation is the negative correlation between overall rank and GDP per capita.

# %% [markdown]
# # 04. Scatterplots

# %%
sns.lmplot(x ='Overall rank', y = 'GDP per capita', data = df_2019_prepared_sub)

# %% [markdown]
# ## There is a negative correlation between the GDP per capita and overall rank

# %%
sns.lmplot(x = 'GDP per capita', y = 'Healthy life expectancy', data = df_2019_prepared_sub)

# %% [markdown]
# ## There is a strong positive correlation between GDP per capita and Healthy life expectancy

# %%
sns.lmplot(x = 'GDP per capita', y = 'Social support',data = df_2019_prepared_sub)

# %% [markdown]
# ## There is a strong positive correlation between GDP per capita and Social Support

# %% [markdown]
# # 05. Pair Plots

# %%
p1 = sns.pairplot(df_2015_prepared_sub)

# %%
p2 = sns.pairplot(df_2016_prepared_sub)

# %%
p3 = sns.pairplot(df_2017_prepared_sub)

# %%
p4 = sns.pairplot(df_2018_prepared_sub)

# %%
p5 = sns.pairplot(df_2019_prepared_sub)

# %% [markdown]
# # 06. Categorical Plots
#
# ## GDP per capita vs overall rank

# %%
sns.histplot(df_2019_prepared_sub['GDP per capita'], bins = 20, kde = True)
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='Count'>

# %%
df_2019_prepared_sub.loc[df_2019_prepared_sub['GDP per capita'] < 0.75, 'GDP per capita category'] = 'Low GDP per capita'

# %%
df_2019_prepared_sub.loc[(df_2019_prepared_sub['GDP per capita'] > 0.75) & (df_2019_prepared_sub['GDP per capita'] < 1.25), 'GDP per capita category'] = 'Medium GDP per capita'

# %%
df_2019_prepared_sub.loc[df_2019_prepared_sub['GDP per capita'] > 1.25, 'GDP per capita category'] = 'High GDP per capita'

# %%
df_2019_prepared_sub['GDP per capita category'].value_counts(dropna = False)
# Out:
# Medium GDP per capita    69
# Low GDP per capita       51
# High GDP per capita      36
# Name: GDP per capita category, dtype: int64

# %%
df_2019_prepared_sub.columns
# Out:
# Index(['Overall rank', 'Country', 'GDP per capita', 'Social support',
#        'Healthy life expectancy', 'Freedom to make life choices',
#        'Perceptions of corruption', 'GDP per capita category'],
#       dtype='object')

# %%
sns.set(style = "ticks")

g = sns.catplot(x="GDP per capita", y="Overall rank", hue="GDP per capita category", data=df_2019_prepared_sub)

# %%
g.savefig("out.png")

# %% [markdown]
# # 07. Key Questions
#
# ## What factors contribute to high ranks of the countries when analyzing their happiness? Which factors seem to have the most influence on a country’s happiness?
#
#
# GDP per capita, social support and healthy life expectancy contribute to high ranks of the countries when analyzing their happiness.
#
#
#
# ## Are there any correlations between different factors that affect happiness?
#
# There is a negative correlation between the GDP per capita and overall rank.
# There is a strong positive correlation between GDP per capita and Social Support
# There is a strong positive correlation between GDP per capita and Healthy life expectancy.

# %% [markdown]
# # 08. Hypotheses
#
# I am not sure if I have explored all the variables enough at this stage to form a hypotheses. My aim here is to analyse different factors that contribute to the happiness of a country. I got to know from the recent analysis that GDP per capita, social support and healthy life expectancy are among the main variables that help to detemine the overall happiness rank of a country.
#
# I can potentially , with the analysis done till now, test : 'The higher the healthy life expectancy and social support factor of a country, the higher the happiness rank of that country.'
